# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [WSL](#toc1_)
# - 2. [--50系列显卡Docker运行vllm](#toc2_)
#   - 2.1. [前言](#toc2_1_)
#   - 2.2. [安装WSL](#toc2_2_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # 1. <a id='toc1_'></a>[WSL](#toc0_)

# %% [markdown]
# # 2. <a id='toc2_'></a>[--50系列显卡Docker运行vllm](#toc0_)

# %% [markdown]
# ## 2.1. <a id='toc2_1_'></a>[前言](#toc0_)

# %% [markdown]
# 环境准备：
#
# --WSL
#
# --Docker Desktop
#
# --英伟达驱动
#
# --NVIDIA Container Toolkit

# %% [markdown]
# <img src="./Image/1.png" style="margin-left: 0" width="50%">

# %% [markdown]
# ## 2.2. <a id='toc2_2_'></a>[安装WSL](#toc0_)

# %% [markdown]
# [WSL安装教程](#WSL)
