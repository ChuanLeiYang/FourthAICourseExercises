# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [LlamaIndex简介](#toc1_)
#   - 1.1. [什么是LlamaIndex](#toc1_1_)
#   - 1.2. [LlamaIndex为何而生？](#toc1_2_)
#   - 1.3. [LlamaIndex如何破局？](#toc1_3_)
#   - 1.4. [核心概念-RAG](#toc1_4_)
#     - 1.4.1. [RAG](#toc1_4_1_)
#       - 1.4.1.1. [索引阶段](#toc1_4_1_1_)
#       - 1.4.1.2. [查询阶段](#toc1_4_1_2_)
# - 2. [案例](#toc2_)
#   - 2.1. [环境搭建](#toc2_1_)
#     - 2.1.1. [创建虚拟环境](#toc2_1_1_)
#     - 2.1.2. [安装LlamaIndex](#toc2_1_2_)
#     - 2.1.3. [安装huggingface包](#toc2_1_3_)
#     - 2.1.4. [安装huggingface核心包](#toc2_1_4_)
#   - 2.2. [下载embedding_model](#toc2_2_)
#   - 2.3. [测试没有RAG知识库的效果](#toc2_3_)
#   - 2.4. [采用RAG知识库的效果](#toc2_4_)
# - 3. [图片格式](#toc3_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # 1. <a id='toc1_'></a>[LlamaIndex简介](#toc0_)

# %% [markdown]
# [LlamaIndex英文文档](https://docs.llamaindex.ai/en/stable/)

# %% [markdown]
# ## 1.1. <a id='toc1_1_'></a>[什么是LlamaIndex](#toc0_)

# %% [markdown]
# LlamaIndex 是一个用于 LLM 应用程序的数据框架，用于注入，结构化，并访问私有或特定领域数据。

# %% [markdown]
# ## 1.2. <a id='toc1_2_'></a>[LlamaIndex为何而生？](#toc0_)

# %% [markdown]
# 在本质上，LLM（如GPT）为人类和推断出的数据提供了基于自然语言的交互接口。广泛可用的大模型通常在大量公开可用的数据上进行的预训练，包括来自维基百科、邮件列表、书籍和源代码等。构建在LLM模型之上的应用程序通常需要使用私有或特定领域数据来增强这些模型。不幸的是，这些数据可能分布在不同的应用程序和数据存储中。它们可能存在于API之后、SQL数据库中，或者存在在PDF文件以及幻灯片中。LlamaIndex应运而生。

# %% [markdown]
# <img src="./Image/2025-05-26-21-03-56.png" style="margin-left: 0" width="70%">

# %% [markdown]
# ## 1.3. <a id='toc1_3_'></a>[LlamaIndex如何破局？](#toc0_)

# %% [markdown]
# LlamaIndex 提供了5大核心工具： \
#  Data connectors：数据连接器 \
#  Data indexes：把文本向量化，然后进行检索 \
#  Engines：引擎，用于加载模型 \
#  Data agents \
#  Application integrations

# %% [markdown]
# <img src="./Image/2025-05-26-21-13-40.png" style="margin-left: 0" width="70%">

# %% [markdown]
# ## 1.4. <a id='toc1_4_'></a>[核心概念-RAG](#toc0_)

# %% [markdown]
# LlamaIndex 帮助构建LLM 驱动的，基于个人或私域数据的应用。RAG(Retrieval Augmented Generation) 是 LlamaIndex 应用的核心概念。

# %% [markdown]
# ### 1.4.1. <a id='toc1_4_1_'></a>[RAG](#toc0_)

# %% [markdown]
# RAG，也称为检索增强生成，是利用个人或私域数据增强LLM 的一种范式。通常，它包含两个阶段：
# 1. 索引
#
# 构建知识库。
#
# 2. 查询
#
# 从知识库检索相关上下文信息，以辅助LLM 回答问题。
#
# LlamaIndex 提供了工具包帮助开发者极其便捷地完成这两个阶段的工作。

# %% [markdown]
# #### 1.4.1.1. <a id='toc1_4_1_1_'></a>[索引阶段](#toc0_)

# %% [markdown]
# LlamaIndex 通过提供 Data connectors(数据连接器) 和 Indexes (索引) 帮助开发者构建知识库。 \
# 该阶段会用到如下工具或组件： \
#
# ----Data connectors \
# 数据连接器。它负责将来自不同数据源的不同格式的数据注入，并转换为 档（Document）表现形式，其中包含了文本和元数据。 \
#
# ----Documents / Nodes \
# Document是 LlamaIndex 中容器的概念，它可以包含任何数据源，包括，PDF文档，API响应，或来自数据库的数据。 \
#
# Node是 LlamaIndex 中数据的最小单元，代表了一个 Document的分块。它还包含了元数据，以及与其他Node的关系信息。这使得更精确的检索操作成为可能。 \
#
# ----Data Indexes \
# LlamaIndex 提供便利的工具，帮助开发者为注入的数据建立索引，使得未来的检索简单而高效。最常用的索引是向量存储索引 - VectorStoreIndex 。

# %% [markdown]
# <img src="./Image/2025-05-26-21-32-02.png" style="margin-left: 0" width="70%">

# %% [markdown]
# #### 1.4.1.2. <a id='toc1_4_1_2_'></a>[查询阶段](#toc0_)

# %% [markdown]
# 在查询阶段，RAG 管道根据的用户查询，检索最相关的上下文，并将其与查询一起，传递给合成响应。这使
# LLM ，以LLM 能够获得不在其原始训练数据中的最新知识，同时也减少了虚构内容。该阶段的关键挑战在于检索、编排和基于知识库的推理。
#
# LlamaIndex 提供可组合的模块，帮助开发者构建和集成RAG 管道，用于问答、聊天机器人或作为代理的一部分。这些构建块可以根据排名偏好进行定制，并组合起来，以结构化的方式基于多个知识库进行推理。
#
# 该阶段的构建块包括：
#
# ----Retrievers \
# 检索器。它定义如何高效地从知识库，基于查询，检索相关上下文信息。 \
#
# ----Node Postprocessors \
#  Node后处理器。它对一系列文档节点（Node）实施转换，过滤，或排名。 \
#
# ----Response Synthesizers \
# 响应合成器。它基于用户的查询，和一组检索到的文本块（形成上下文），利用LLM生成响应。
#
# RAG管道包括：
#
# ----Query Engines \
#  LLM 生成响应。
# 查询引擎 - 端到端的管道，允许用户基于知识库，以自然语言提问，并获得回答，以及相关的上下文。
#
# ----Chat Engines
# 聊天引擎 - 端到端的管道，允许用户基于知识库进行对话（多次交互，会话历史）。
#
# ----Agents
# 代理。它是一种由LLM 驱动的自动化决策器。代理可以像查询引擎或聊天引擎一样使用。主要区别在于，代理动态地决定最佳的动作序列，而不是遵循预定的逻辑。这为其提供了处理更复杂任务的额外灵活性

# %% [markdown]
# <img src="./Image/2025-05-26-22-15-25.png" style="margin-left: 0" width="70%">

# %% [markdown]
# # 2. <a id='toc2_'></a>[案例](#toc0_)

# %% [markdown]
# ## 2.1. <a id='toc2_1_'></a>[环境搭建](#toc0_)

# %% [markdown]
# ### 2.1.1. <a id='toc2_1_1_'></a>[创建虚拟环境](#toc0_)

# %% [markdown]
# conda create -n envllamaindex python==3.12 -y
#
# conda activate envllamaindex

# %% [markdown]
# ### 2.1.2. <a id='toc2_1_2_'></a>[安装LlamaIndex](#toc0_)

# %% [markdown]
# pip install llama-index -i https://pypi.tuna.tsinghua.edu.cn/simple

# %% [markdown]
# ### 2.1.3. <a id='toc2_1_3_'></a>[安装huggingface包](#toc0_)

# %% [markdown]
# [huggingface包官方安装方法](https://docs.llamaindex.ai/en/stable/examples/llm/huggingface/)

# %% [markdown]
# pip install llama-index-llms-huggingface
#
# 可以镜像加速
#
# pip install llama-index-llms-huggingface -i https://pypi.tuna.tsinghua.edu.cn/simple

# %% [markdown]
# ### 2.1.4. <a id='toc2_1_4_'></a>[安装huggingface核心包](#toc0_)

# %% [markdown]
# pip install llama_index.embeddings.huggingface -i https://pypi.tuna.tsinghua.edu.cn/simple

# %% [markdown]
# ## 2.2. <a id='toc2_2_'></a>[下载embedding_model](#toc0_)

# %% [markdown]
# 从modelscope下载sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2模型作为embedding_model,modeldownload.py内容如下：

# %%
#模型下载
from modelscope import snapshot_download
model_dir = snapshot_download('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2',cache_dir='/root/AI-WSL/models/embedding_model')

# %% [markdown]
# 执行模型下载.py文件
#
# python /root/AI-WSL/project/projectLlamaIndex/code/modeldownload.py

# %% [markdown]
# 这是一个sentence-transformers模型：它将句子和段落映射到一个384维的密集向量空间，并可用于聚类或语义搜索等任务。

# %% [markdown]
# <img src="./Image/2025-05-26-22-50-57.png" style="margin-left: 0" width="60%">

# %% [markdown]
# ## 2.3. <a id='toc2_3_'></a>[测试没有RAG知识库的效果](#toc0_)

# %% [markdown]
# test01_WithoutRAG.py

# %%
from llama_index.core.llms import ChatMessage
from llama_index.llms.huggingface import HuggingFaceLLM

#使用HuggingFaceLLM加载本地大模型,model_name和tokenizer_name都指向本地模型路径
#model_kwargs和tokenizer_kwargs都设置trust_remote_code为True，表示允许使用远程代码
llm = HuggingFaceLLM(model_name="/root/AI-WSL/models/Qwen/Qwen1.5-1.8B-Chat",
               tokenizer_name="/root/AI-WSL/models/Qwen/Qwen1.5-1.8B-Chat",
               model_kwargs={"trust_remote_code":True},
               tokenizer_kwargs={"trust_remote_code":True})
#调用模型chat引擎得到回复
rsp = llm.chat(messages=[ChatMessage(content="xtuner是什么？")])

print(rsp)

# %% [markdown]
# 执行代码测试

# %% [markdown]
# python /root/AI-WSL/project/projectLlamaIndex/code/test01_WithoutRAG.py

# %% [markdown]
# ![](Image/2025-05-26-23-16-37.png)

# %% [markdown]
# 如图所示，它会一本正经的胡说八道。

# %% [markdown]
# ## 2.4. <a id='toc2_4_'></a>[采用RAG知识库的效果](#toc0_)

# %% [markdown]
# test02_WithRAG.py

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings,SimpleDirectoryReader,VectorStoreIndex
from llama_index.llms.huggingface import HuggingFaceLLM

#初始化一个HuggingFaceEmbedding对象，用于将文本转换为向量表示
embed_model = HuggingFaceEmbedding(
    #指定了一个预训练的sentence-transformer模型的路径
    model_name="/root/AI-WSL/models/embedding_model/sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
)

#将创建的嵌入模型赋值给全局设置的embed_model属性，这样在后续的索引构建过程中，就会使用这个模型
Settings.embed_model = embed_model

#使用HuggingFaceLLM加载本地大模型
llm = HuggingFaceLLM(model_name="/root/AI-WSL/models/Qwen/Qwen1.5-1.8B-Chat",
               tokenizer_name="/root/AI-WSL/models/Qwen/Qwen1.5-1.8B-Chat",
               model_kwargs={"trust_remote_code":True},
               tokenizer_kwargs={"trust_remote_code":True})
#设置全局的llm属性，这样在索引查询时会使用这个模型。
Settings.llm = llm

#从指定目录读取文档，将数据加载到内存，注意给的是文件夹的路径，不能给单个文件的路径
documents = SimpleDirectoryReader("/root/AI-WSL/project/projectLlamaIndex/data").load_data()
#print(documents)
#创建一个VectorStoreIndex,并使用之前加载的文档来构建向量索引
#此索引将文档转换为向量，并存储这些向量（内存）以便于快速检索
index = VectorStoreIndex.from_documents(documents)
#创建一个查询引擎，这个引擎可以接收查询并返回相关文档的响应。
query_engine = index.as_query_engine()
rsp = query_engine.query("xtuner是什么？")
print(rsp)

# %% [markdown]
# (envllamaindex) root@nishuixingzhou:~# python /root/AI-WSL/project/projectLlamaIndex/code/test02_WithRAG.py

# %% [markdown]
# 答复内容；
#
# 上传的脚本 `README_zh-CN.md` 中提到的 XTuner 是一个用于高效地微调大型语言模型（如 [InternLM](https://huggingface.co/internlm) 或 [Mixtral-8x7B](https://huggingface.co/mistralai)）的工具包。它允许用户指定微调模型大小（7B 或更大）以及微调算法（如 [DeepSpeed](https://github.com/microsoft/DeepSpeed)）。该脚本包含以下信息：
# - 模型：内置多种已训练的大规模语言模型，如 [InternLM](https://huggingface.co/internlm)、[Mixtral-8x7B](https://huggingface.co/mistralai)，以及 [LLaVA](https://huggingface.co/mistralai/L-LaVA-InternLM2-20B)。
# - 数据集：支持多种大语言模型的数据集，包括但不限于 [InternLM](https://huggingface.co/internlm)、[Mixtral-8x7B](https://huggingface.co/mistralai)、[Llama 2](https://huggingface.co/meta-

# %% [markdown]
# 可以看到答复内容包含了上传数据中的内容

# %% [markdown]
# ![](Image/2025-05-26-23-31-24.png)

# %% [markdown]
# # 3. <a id='toc3_'></a>[图片格式](#toc0_)

# %% [markdown]
# <img src="./Image/2025-05-22-22-35-11.png" style="margin-left: 0" width="30%">
